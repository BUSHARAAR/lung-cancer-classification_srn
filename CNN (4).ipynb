# %% [markdown]
# Lung histopathology

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# importing libraries

import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score, roc_auc_score, cohen_kappa_score, precision_score, recall_score, accuracy_score, confusion_matrix
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input
from keras.models import Sequential
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
#from keras.layers.normalization import BatchNormalization
from keras.models import Model, Sequential
from keras.applications.xception import Xception
from keras.applications import *
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from PIL import Image
import random
import os
import cv2
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from keras.callbacks import EarlyStopping
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
from sklearn.decomposition import PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image_set= '/content/drive/MyDrive/lung_image_sets'

# %%
for i,d in enumerate([image_set]):
    filepaths=[]
    labels=[]
    classlist=os.listdir(d)
    for klass in classlist:
        classpath=os.path.join(d,klass)
        if os.path.isdir(classpath):
            flist=os.listdir(classpath)
            for f in flist:
                fpath=os.path.join(classpath,f)
                filepaths.append(fpath)
                labels.append(klass)
    Fseries= pd.Series(filepaths, name='filepaths')
    Lseries=pd.Series(labels, name='labels')
    lung_df=pd.concat([Fseries, Lseries], axis=1)
df=pd.concat([lung_df], axis =0).reset_index(drop=True)# make a combined dataframe

print(df['labels'].value_counts())
# Out:
# lung_aca    5010
# lung_scc    5000
# lung_n      5000
# Name: labels, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
train_split=.5
test_split=.25
dummy_split=test_split/(1-train_split)
train_df, dummy_df=train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
test_df, valid_df=train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print ('train_df length: ', len(train_df), ' _test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df length:  7505  _test_df length:  3752   valid_df length:  3753

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
height=224
width=224
channels=3
batch_size=32
img_shape=(height, width, channels)
img_size=(height, width)
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]
test_steps=int(length/test_batch_size)
print ('test batch size: ' ,test_batch_size, '  test steps: ', test_steps)
def scalar(img):
    return img/127.5-1  # scale pixel between -1 and +1
gen=ImageDataGenerator(preprocessing_function=scalar)
train_set=gen.flow_from_dataframe( train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)
test_set=gen.flow_from_dataframe( test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=False, batch_size=test_batch_size)
validate_set=gen.flow_from_dataframe( valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)
#classes=list(train_gen.class_indices.keys())
#class_count=len(classes)
# Out:
# test batch size:  67   test steps:  56
# Found 7505 validated image filenames belonging to 3 classes.
# Found 3752 validated image filenames belonging to 3 classes.
# Found 3753 validated image filenames belonging to 3 classes.

# %%
IMAGE_SIZE = [224, 224]

# %%
# importing libraries

import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
from  tensorflow import keras

# %%
# import os                       # for working with files
# import numpy as np              # for numerical computationss
# import pandas as pd             # for working with dataframes
# import seaborn as sns
# import torch                    # Pytorch module
# import matplotlib.pyplot as plt # for plotting informations on graph and images using tensors
# import torch.nn as nn           # for creating  neural networks
# from torch.utils.data import DataLoader # for dataloaders
# from PIL import Image           # for checking images
# import torch.nn.functional as F # for functions for calculating loss
# import torchvision.transforms as transforms   # for transforming images into tensors
# from torchvision.utils import make_grid       # for data checking
# from torchvision.datasets import ImageFolder  # for working with classes and images
# from torchsummary import summary              # for getting the summary of our model
# import tensorflow as ts
# from  tensorflow import keras
# import itertools
# from sklearn.metrics import precision_score, accuracy_score, recall_score, confusion_matrix, ConfusionMatrixDisplay

# %matplotlib inline

# %%
model_1 = keras.models.Sequential()

model_1.add(keras.layers.Conv2D(32, 3, activation='relu', input_shape=(224, 224, 3)))

model_1.add(keras.layers.Dropout(0.1))
model_1.add(keras.layers.MaxPooling2D())

model_1.add(keras.layers.Conv2D(64, 3, activation='relu'))
model_1.add(keras.layers.Dropout(0.15))
model_1.add(keras.layers.MaxPooling2D())

model_1.add(keras.layers.Conv2D(128, 3, activation='relu'))
model_1.add(keras.layers.Dropout(0.2))
model_1.add(keras.layers.MaxPooling2D())

model_1.add(keras.layers.Flatten())
model_1.add(keras.layers.Dense(256, activation='relu'))
model_1.add(keras.layers.Dense(3, activation='softmax'))

model_1.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  dropout (Dropout)           (None, 222, 222, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  dropout_1 (Dropout)         (None, 109, 109, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  dropout_2 (Dropout)         (None, 52, 52, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 256)               22151424
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 22,245,443
# Trainable params: 22,245,443
# Non-trainable params: 0
# _________________________________________________________________

# %%
# COMPILING THE MODEL

model_1.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
#executing the model
history = model_1.fit(train_set, validation_data = (validate_set), epochs = 50, verbose = 1)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 1919s 8s/step - loss: 0.5255 - accuracy: 0.8227 - val_loss: 0.2690 - val_accuracy: 0.8854
# Epoch 2/50
# 235/235 [==============================] - 63s 268ms/step - loss: 0.2320 - accuracy: 0.9089 - val_loss: 0.2417 - val_accuracy: 0.9057
# Epoch 3/50
# 235/235 [==============================] - 62s 262ms/step - loss: 0.1789 - accuracy: 0.9316 - val_loss: 0.2316 - val_accuracy: 0.9225
# Epoch 4/50
# 235/235 [==============================] - 63s 270ms/step - loss: 0.1231 - accuracy: 0.9514 - val_loss: 0.2097 - val_accuracy: 0.9262
# Epoch 5/50
# 235/235 [==============================] - 64s 270ms/step - loss: 0.0785 - accuracy: 0.9711 - val_loss: 0.1868 - val_accuracy: 0.9265
# Epoch 6/50
# 235/235 [==============================] - 62s 263ms/step - loss: 0.0743 - accuracy: 0.9718 - val_loss: 0.2011 - val_accuracy: 0.9259
# Epoch 7/50
# 235/235 [==============================] - 61s 258ms/step - loss: 0.0404 - accuracy: 0.9856 - val_loss: 0.2106 - val_accuracy: 0.9278
# Epoch 8/50
# 235/235 [==============================] - 61s 259ms/step - loss: 0.0363 - accuracy: 0.9896 - val_loss: 0.2005 - val_accuracy: 0.9278
# Epoch 9/50
# 235/235 [==============================] - 63s 266ms/step - loss: 0.0326 - accuracy: 0.9893 - val_loss: 0.1778 - val_accuracy: 0.9496
# Epoch 10/50
# 235/235 [==============================] - 61s 258ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.2198 - val_accuracy: 0.9446
# Epoch 11/50
# 235/235 [==============================] - 63s 268ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.2146 - val_accuracy: 0.9411
# Epoch 12/50
# 235/235 [==============================] - 62s 263ms/step - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.2145 - val_accuracy: 0.9454
# Epoch 13/50
# 235/235 [==============================] - 65s 276ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.2768 - val_accuracy: 0.9376
# Epoch 14/50
# 235/235 [==============================] - 64s 272ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.3878 - val_accuracy: 0.9105
# Epoch 15/50
# 235/235 [==============================] - 65s 275ms/step - loss: 0.0595 - accuracy: 0.9825 - val_loss: 0.2819 - val_accuracy: 0.9142
# Epoch 16/50
# 235/235 [==============================] - 64s 274ms/step - loss: 0.0274 - accuracy: 0.9921 - val_loss: 0.2226 - val_accuracy: 0.9435
# Epoch 17/50
# 235/235 [==============================] - 64s 271ms/step - loss: 0.0112 - accuracy: 0.9975 - val_loss: 0.2668 - val_accuracy: 0.9339
# Epoch 18/50
# 235/235 [==============================] - 62s 264ms/step - loss: 0.0109 - accuracy: 0.9968 - val_loss: 0.2210 - val_accuracy: 0.9392
# Epoch 19/50
# 235/235 [==============================] - 64s 272ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.2621 - val_accuracy: 0.9443
# Epoch 20/50
# 235/235 [==============================] - 62s 265ms/step - loss: 1.1348e-04 - accuracy: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9448
# Epoch 21/50
# 235/235 [==============================] - 65s 276ms/step - loss: 8.3282e-05 - accuracy: 1.0000 - val_loss: 0.2626 - val_accuracy: 0.9470
# Epoch 22/50
# 235/235 [==============================] - 69s 294ms/step - loss: 5.8048e-05 - accuracy: 1.0000 - val_loss: 0.2654 - val_accuracy: 0.9464
# Epoch 23/50
# 235/235 [==============================] - 69s 294ms/step - loss: 3.9434e-05 - accuracy: 1.0000 - val_loss: 0.2712 - val_accuracy: 0.9480
# Epoch 24/50
# 235/235 [==============================] - 66s 280ms/step - loss: 3.5669e-05 - accuracy: 1.0000 - val_loss: 0.2721 - val_accuracy: 0.9475
# Epoch 25/50
# 235/235 [==============================] - 65s 279ms/step - loss: 2.6293e-05 - accuracy: 1.0000 - val_loss: 0.2801 - val_accuracy: 0.9475
# Epoch 26/50
# 235/235 [==============================] - 62s 263ms/step - loss: 2.9027e-05 - accuracy: 1.0000 - val_loss: 0.2799 - val_accuracy: 0.9472
# Epoch 27/50
# 235/235 [==============================] - 64s 274ms/step - loss: 1.9952e-05 - accuracy: 1.0000 - val_loss: 0.2838 - val_accuracy: 0.9486
# Epoch 28/50
# 235/235 [==============================] - 64s 274ms/step - loss: 2.0185e-05 - accuracy: 1.0000 - val_loss: 0.2905 - val_accuracy: 0.9486
# Epoch 29/50
# 235/235 [==============================] - 69s 293ms/step - loss: 1.2709e-05 - accuracy: 1.0000 - val_loss: 0.2895 - val_accuracy: 0.9488
# Epoch 30/50
# 235/235 [==============================] - 68s 288ms/step - loss: 1.3552e-05 - accuracy: 1.0000 - val_loss: 0.2920 - val_accuracy: 0.9488
# Epoch 31/50
# 235/235 [==============================] - 69s 293ms/step - loss: 9.5852e-06 - accuracy: 1.0000 - val_loss: 0.2977 - val_accuracy: 0.9494
# Epoch 32/50
# 235/235 [==============================] - 67s 285ms/step - loss: 9.4555e-06 - accuracy: 1.0000 - val_loss: 0.3027 - val_accuracy: 0.9496
# Epoch 33/50
# 235/235 [==============================] - 62s 263ms/step - loss: 7.4726e-06 - accuracy: 1.0000 - val_loss: 0.3042 - val_accuracy: 0.9491
# Epoch 34/50
# 235/235 [==============================] - 64s 274ms/step - loss: 6.4056e-06 - accuracy: 1.0000 - val_loss: 0.3054 - val_accuracy: 0.9491
# Epoch 35/50
# 235/235 [==============================] - 66s 283ms/step - loss: 6.1507e-06 - accuracy: 1.0000 - val_loss: 0.3080 - val_accuracy: 0.9494
# Epoch 36/50
# 235/235 [==============================] - 64s 271ms/step - loss: 4.5906e-06 - accuracy: 1.0000 - val_loss: 0.3099 - val_accuracy: 0.9496
# Epoch 37/50
# 235/235 [==============================] - 64s 271ms/step - loss: 3.6695e-06 - accuracy: 1.0000 - val_loss: 0.3155 - val_accuracy: 0.9488
# Epoch 38/50
# 235/235 [==============================] - 63s 270ms/step - loss: 3.7037e-06 - accuracy: 1.0000 - val_loss: 0.3160 - val_accuracy: 0.9496
# Epoch 39/50
# 235/235 [==============================] - 63s 267ms/step - loss: 2.7937e-06 - accuracy: 1.0000 - val_loss: 0.3214 - val_accuracy: 0.9496
# Epoch 40/50
# 235/235 [==============================] - 62s 264ms/step - loss: 3.4230e-06 - accuracy: 1.0000 - val_loss: 0.3297 - val_accuracy: 0.9499
# Epoch 41/50
# 235/235 [==============================] - 65s 275ms/step - loss: 3.2089e-06 - accuracy: 1.0000 - val_loss: 0.3301 - val_accuracy: 0.9499
# Epoch 42/50
# 235/235 [==============================] - 65s 274ms/step - loss: 1.8670e-06 - accuracy: 1.0000 - val_loss: 0.3352 - val_accuracy: 0.9499
# Epoch 43/50
# 235/235 [==============================] - 65s 275ms/step - loss: 1.8277e-06 - accuracy: 1.0000 - val_loss: 0.3411 - val_accuracy: 0.9499
# Epoch 44/50
# 235/235 [==============================] - 65s 277ms/step - loss: 1.7403e-06 - accuracy: 1.0000 - val_loss: 0.3374 - val_accuracy: 0.9496
# Epoch 45/50
# 235/235 [==============================] - 63s 267ms/step - loss: 1.1876e-06 - accuracy: 1.0000 - val_loss: 0.3428 - val_accuracy: 0.9499
# Epoch 46/50
# 235/235 [==============================] - 65s 277ms/step - loss: 1.1738e-06 - accuracy: 1.0000 - val_loss: 0.3463 - val_accuracy: 0.9494
# Epoch 47/50
# 235/235 [==============================] - 68s 288ms/step - loss: 1.0334e-06 - accuracy: 1.0000 - val_loss: 0.3443 - val_accuracy: 0.9496
# Epoch 48/50
# 235/235 [==============================] - 65s 275ms/step - loss: 7.4071e-07 - accuracy: 1.0000 - val_loss: 0.3494 - val_accuracy: 0.9491
# Epoch 49/50
# 235/235 [==============================] - 61s 261ms/step - loss: 8.3310e-07 - accuracy: 1.0000 - val_loss: 0.3524 - val_accuracy: 0.9494
# Epoch 50/50
# 235/235 [==============================] - 63s 269ms/step - loss: 8.7659e-07 - accuracy: 1.0000 - val_loss: 0.3612 - val_accuracy: 0.9472

# %%
# plotting the loss
plt.plot(history.history['loss'],label = 'Training loss')
plt.plot(history.history['val_loss'], label = 'Validation loss')
#plt.title('loss')
plt.legend()
plt.show()

# %%
# Both Validation and Training accuracy is shown here

plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
#plt.title('Accuracy')
plt.legend()
plt.show()

# %%
# CHECKING THE CONFUSION MATRIX

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
Y_pred = model_1.predict(test_set)
y_pred = np.argmax(Y_pred ,axis =1)
# Out:
# 56/56 [==============================] - 607s 11s/step

# %%
preds = model_1.predict(test_set,verbose=1)
predictions = preds.copy()
predictions[predictions <= 0.5] = 0
predictions[predictions > 0.5] = 1
# Out:
# 56/56 [==============================] - 21s 383ms/step

# %%
from sklearn.metrics import classification_report,confusion_matrix
cm = pd.DataFrame(data=confusion_matrix( y_true= test_set.classes, y_pred= y_pred, labels=[0, 1,2]), index=['Actual lung_aca','Actual lung_n','Actual lung_scc'],columns=['Preicted lung_aca','Preicted lung_n','Preicted lung_scc'])
import seaborn as sns
sns.heatmap(cm,annot=True,fmt="d",cmap="YlGn")
# Out:
# <Axes: >

# %%
print('Classification Report')
target_names = ['lung_aca','lung_n','lung_scc']
print(classification_report(test_set.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#     lung_aca       0.95      0.90      0.93      1254
#       lung_n       1.00      0.99      0.99      1233
#     lung_scc       0.91      0.97      0.94      1265
#
#     accuracy                           0.95      3752
#    macro avg       0.95      0.95      0.95      3752
# weighted avg       0.95      0.95      0.95      3752

# %%
loss, acc = model_1.evaluate_generator(test_set, len(test_set))

print ("\n\n================================\n\n")
print ("Loss: {}".format(loss))
print ("Accuracy: {0:.2f} %".format(acc * 100))
print ("\n\n================================\n\n")

test_set.reset()
# Out:
# <ipython-input-21-0bfbb599d6c5>:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   loss, acc = model_1.evaluate_generator(test_set, len(test_set))
# ================================
#
#
# Loss: 0.3208428919315338
# Accuracy: 95.28 %
#
#
# ================================

# %%
result = model_1.evaluate(test_set,batch_size=128)
print("test_loss, test accuracy",result)
# Out:
# 56/56 [==============================] - 21s 370ms/step - loss: 0.3208 - accuracy: 0.9528
# test_loss, test accuracy [0.3208428919315338, 0.9528251886367798]

# %%
#Confusion Matrix and Classification Report
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

#Y_pred = model.predict_generator(validation_generator, nb_validation_samples //
#batch_size+1)
y_pred = np.argmax(preds, axis=1)

print('Confusion Matrix')
print(confusion_matrix(test_set.classes, y_pred))
# Out:
# Confusion Matrix
# [[1132    4  118]
#  [  12 1221    0]
#  [  43    0 1222]]
